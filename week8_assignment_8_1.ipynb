# %% [markdown]
# <a href="https://colab.research.google.com/github/Amara870/2.2-Robotics/blob/main/week8_assignment_8_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# About the data:
#
# Order Value: Represents the total value of the customer's order.
#
# Customer Rating: Represents the rating given by the customer, typically between 1 and 5.
#
# Shipping Time (Days): Represents the number of days taken to deliver the order.
#
#
# **Note: This assignment and dataset have outliers and missing values generated on purpose to help you understand the importance of data cleaning and preprocessing in preparing data for analysis and modeling**

# %%
# Run this cell first and then answer the questions given in the assignment.

import numpy as np
import pandas as pd

np.random.seed(42)

# Generating sample data
data = {
    'Order Value': np.random.normal(100, 20, 30),
    'Customer Rating': np.random.normal(4, 0.5, 30),
    'Shipping Time (Days)': np.random.randint(1, 10, 30)
}

# Introducing missing values and outliers on purpose
data['Order Value'][np.random.choice(30, 8, replace=False)] = np.nan
data['Customer Rating'][np.random.choice(30, 7, replace=False)] = np.nan

data['Order Value'][np.random.choice(30, 7, replace=False)] = [300, 400, 300, 350, 400, 450, 700]
data['Customer Rating'][np.random.choice(30, 5, replace=False)] = [1, 5, 0.5, 5.5, 1]

# Convert to DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#     Order Value  Customer Rating  Shipping Time (Days)
# 0    109.934283         3.699147                     2
# 1     97.234714         4.926139                     1
# 2    112.953771         3.993251                     7
# 3    130.460597              NaN                     7
# 4           NaN         1.000000                     8
# 5     95.317261              NaN                     5
# 6    400.000000         4.104432                     3
# 7    700.000000         3.020165                     8
# 8     90.610512         3.335907                     6
# 9    350.000000              NaN                     3
# 10    90.731646         4.369233                     1
# 11    90.685405         4.085684                     3
# 12   450.000000         3.942176                     5
# 13   400.000000         1.000000                     3
# 14    65.501643         5.000000                     1
# 15          NaN         0.500000                     5
# 16    79.743378         3.769681                     7
# 17   300.000000              NaN                     7
# 18    81.839518              NaN                     9
# 19    71.753926         3.118480                     3
# 20   129.312975         5.500000                     7
# 21    95.484474         3.807459                     1
# 22          NaN         3.661539                     4
# 23          NaN         4.305838                     4
# 24    89.112346         4.515500                     5
# 25   102.218452         4.465640                     7
# 26          NaN         3.580391                     7
# 27   107.513960         3.845394                     4
# 28          NaN         4.165632                     7
# 29   300.000000         4.487773                     3

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

# Generating sample data
data = {
    'Order Value': np.random.normal(100, 20, 30),
    'Customer Rating': np.random.normal(4, 0.5, 30),
    'Shipping Time (Days)': np.random.randint(1, 10, 30)
}

# Introducing missing values and outliers on purpose
data['Order Value'][np.random.choice(30, 8, replace=False)] = np.nan
data['Customer Rating'][np.random.choice(30, 7, replace=False)] = np.nan

data['Order Value'][np.random.choice(30, 7, replace=False)] = [300, 400, 300, 350, 400, 450, 700]
data['Customer Rating'][np.random.choice(30, 5, replace=False)] = [1, 5, 0.5, 5.5, 1]

# Convert to DataFrame
df = pd.DataFrame(data)

# use pandas to indentify and count missing values
# isna() returns mask of each cell
missing_counts = df.isna().sum()
print("\n=== Missing Value Countp per Column ===")
print(missing_counts)

missing_pct = df.isna().sum() * 100
missing_summary = pd.DataFrame({
    "missing_counts": missing_counts,
    "missing_pct": missing_pct.round(2)})
print("\n=== Missing Value Summary (Count and %) ===")
print(missing_summary)
# Out:
# === Missing Value Countp per Column ===
# Order Value             6
# Customer Rating         5
# Shipping Time (Days)    0
# dtype: int64
#
# === Missing Value Summary (Count and %) ===
#                       missing_counts  missing_pct
# Order Value                        6          600
# Customer Rating                    5          500
# Shipping Time (Days)               0            0

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

# Generating sample data
data = {
    'Order Value': np.random.normal(100, 20, 30),
    'Customer Rating': np.random.normal(4, 0.5, 30),
    'Shipping Time (Days)': np.random.randint(1, 10, 30)
}

# Introducing missing values and outliers on purpose
data['Order Value'][np.random.choice(30, 8, replace=False)] = np.nan
data['Customer Rating'][np.random.choice(30, 7, replace=False)] = np.nan

data['Order Value'][np.random.choice(30, 7, replace=False)] = [300, 400, 300, 350, 400, 450, 700]
data['Customer Rating'][np.random.choice(30, 5, replace=False)] = [1, 5, 0.5, 5.5, 1]

# Convert to DataFrame
df = pd.DataFrame(data)

# implement different strats for handling missing data
#strat A - dropping rows with ANY missing values
df_drop_rows = df.dropna() #removes any rows that has at least one NaN
print("\n === Strategy A: Drop Rows with Any NaNs ===")
print("new shape: ", df_drop_rows.shape)
print("Remaining NaNs: \n", df_drop_rows.isna().sum())
# Out:
#  === Strategy A: Drop Rows with Any NaNs ===
# new shape:  (19, 3)
# Remaining NaNs:
#  Order Value             0
# Customer Rating         0
# Shipping Time (Days)    0
# dtype: int64

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

# Generating sample data
data = {
    'Order Value': np.random.normal(100, 20, 30),
    'Customer Rating': np.random.normal(4, 0.5, 30),
    'Shipping Time (Days)': np.random.randint(1, 10, 30)
}

# Introducing missing values and outliers on purpose
data['Order Value'][np.random.choice(30, 8, replace=False)] = np.nan
data['Customer Rating'][np.random.choice(30, 7, replace=False)] = np.nan

data['Order Value'][np.random.choice(30, 7, replace=False)] = [300, 400, 300, 350, 400, 450, 700]
data['Customer Rating'][np.random.choice(30, 5, replace=False)] = [1, 5, 0.5, 5.5, 1]

# Convert to DataFrame
df = pd.DataFrame(data)

#Strat B - implementing rows with NaNa with the mea
df_fill_mean = df.copy()
df_fill_mean = df_fill_mean.fillna(df_fill_mean.mean(numeric_only=True)) # fill the missing values with the mean
print("\n=== Strategy B: Fill with the Mean ===")
print("Remaining NaNs: \n", df_fill_mean.isna().sum())
# Out:
# === Strategy B: Fill with the Mean ===
# Remaining NaNs:
#  Order Value             0
# Customer Rating         0
# Shipping Time (Days)    0
# dtype: int64

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

# Generating sample data
data = {
    'Order Value': np.random.normal(100, 20, 30),
    'Customer Rating': np.random.normal(4, 0.5, 30),
    'Shipping Time (Days)': np.random.randint(1, 10, 30)
}

# Introducing missing values and outliers on purpose
data['Order Value'][np.random.choice(30, 8, replace=False)] = np.nan
data['Customer Rating'][np.random.choice(30, 7, replace=False)] = np.nan

data['Order Value'][np.random.choice(30, 7, replace=False)] = [300, 400, 300, 350, 400, 450, 700]
data['Customer Rating'][np.random.choice(30, 5, replace=False)] = [1, 5, 0.5, 5.5, 1]

# Convert to DataFrame
df = pd.DataFrame(data)


# Strat C: implementing row with NaNs with median
df_fill_median = df.copy()
df_fill_median = df_fill_median.fillna(df_fill_median.median(numeric_only=True))
print("\n=== Strategy C: Fill NaNs with the Medians ===")
print("Remaining NaNs: \n", df_fill_median.isna().sum())
# Out:
# === Strategy C: Fill NaNs with the Medians ===
# Remaining NaNs:
#  Order Value             0
# Customer Rating         0
# Shipping Time (Days)    0
# dtype: int64

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

# Generating sample data
data = {
    'Order Value': np.random.normal(100, 20, 30),
    'Customer Rating': np.random.normal(4, 0.5, 30),
    'Shipping Time (Days)': np.random.randint(1, 10, 30)
}

# Introducing missing values and outliers on purpose
data['Order Value'][np.random.choice(30, 8, replace=False)] = np.nan
data['Customer Rating'][np.random.choice(30, 7, replace=False)] = np.nan

data['Order Value'][np.random.choice(30, 7, replace=False)] = [300, 400, 300, 350, 400, 450, 700]
data['Customer Rating'][np.random.choice(30, 5, replace=False)] = [1, 5, 0.5, 5.5, 1]

# Convert to DataFrame
df = pd.DataFrame(data)

# Strat D: implementing row with NaNs with mode
df_fill_mode = df.copy()
mode_values = df_fill_mode.mode(numeric_only=True).iloc[0] # for the first mose common mode per column
df_fill_mode = df_fill_mode.fillna(mode_values)
print("\n=== Strategy D: Fill NaNs with Mode ===")
print("Remaining NaNs: \n", df_fill_mode.isna().sum())
# Out:
# === Strategy D: Fill NaNs with Mode ===
# Remaining NaNs:
#  Order Value             0
# Customer Rating         0
# Shipping Time (Days)    0
# dtype: int64

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

# Generating sample data
data = {
    'Order Value': np.random.normal(100, 20, 30),
    'Customer Rating': np.random.normal(4, 0.5, 30),
    'Shipping Time (Days)': np.random.randint(1, 10, 30)
}

# Introducing missing values and outliers on purpose
data['Order Value'][np.random.choice(30, 8, replace=False)] = np.nan
data['Customer Rating'][np.random.choice(30, 7, replace=False)] = np.nan

data['Order Value'][np.random.choice(30, 7, replace=False)] = [300, 400, 300, 350, 400, 450, 700]
data['Customer Rating'][np.random.choice(30, 5, replace=False)] = [1, 5, 0.5, 5.5, 1]

# Convert to DataFrame
df = pd.DataFrame(data)

# quick comparision how how many rows remain vs how many NaNs remain
print("\n=== Quick Strategy Comparison ===")
print({
    "original shape ": df.shape,
    "drop_rows_shape ": df_drop_rows.shape,
    "fill_mean_remaining_nans ": int(df_fill_mean.isna().sum().sum()),
    "fill_median_remaining_nans ": int(df_fill_median.isna().sum().sum()),
    "fill_mode_remaining_nans ": int(df_fill_mode.isna().sum().sum())
})
# Out:
# === Quick Strategy Comparison ===
# {'original shape ': (30, 3), 'drop_rows_shape ': (19, 3), 'fill_mean_remaining_nans ': 0, 'fill_median_remaining_nans ': 0, 'fill_mode_remaining_nans ': 0}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# Generating sample data
data = {
    'Order Value': np.random.normal(100, 20, 30),
    'Customer Rating': np.random.normal(4, 0.5, 30),
    'Shipping Time (Days)': np.random.randint(1, 10, 30)
}

# Introducing missing values and outliers on purpose
data['Order Value'][np.random.choice(30, 8, replace=False)] = np.nan
data['Customer Rating'][np.random.choice(30, 7, replace=False)] = np.nan

data['Order Value'][np.random.choice(30, 7, replace=False)] = [300, 400, 300, 350, 400, 450, 700]
data['Customer Rating'][np.random.choice(30, 5, replace=False)] = [1, 5, 0.5, 5.5, 1]

# Convert to DataFrame
df = pd.DataFrame(data)

# visualize the distribution
# histogram
print("\n=== Plotting Histogram ===")
df.hist(bins=10, figsize=(8,6))
plt.tight_layout()
plt.show()

#Z-Score
# Out:
# === Plotting Histogram ===
